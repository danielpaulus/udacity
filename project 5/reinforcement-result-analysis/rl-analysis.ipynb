# %% [markdown]
# # CGN Result Metric Comparison

# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import ast
import seaborn as sns
#import renders as rs
from IPython.display import display # Allows the use of display() for DataFrames
import copy
import matplotlib.pyplot as plt

file_name= "simulation-statistics.csv"
df= pd.read_csv(file_name)


cgn_df= df[df["scenario"]=="cgn"]
lust_df= df[df["scenario"]=="lust"]




f, axes = plt.subplots(figsize=(25,16), nrows=3, ncols=3)
ax1,ax2, ax33=  axes[0]
ax3,ax4,ax55=  axes[1]
ax5,ax6, ax7=  axes[2]

ax1.set_title("cgn- reinforcement learner")
abs_cgn=cgn_df[cgn_df["clustering_algorithm"]=="clusters_maxabs_3dimensions"]
abs_cgn=abs_cgn[cgn_df["traffic_light_counts"]=="[1, 2, 3, 4]"]
abs_cgn.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax1)

ax2.set_title("cgn- reinforcement learner")
ax2.set_ylim([0,1400])
abs_cgn.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax2)

ax33.set_title("cgn- reinforcement learner")
abs_cgn.plot(x="simulation_steps", y=["DepartDelay"], ax=ax33)



ax3.set_title("cgn- random")
rnd_cgn=cgn_df[cgn_df["clustering_algorithm"]=="random"]
rnd_cgn.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax3)

ax4.set_title("cgn- random")
rnd_cgn.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax4)
ax55.set_title("cgn- random")
ax55.set_ylim([0,3])
rnd_cgn.plot(x="simulation_steps", y=["DepartDelay"], ax=ax55)


ax5.set_title("cgn- scenario controlled")
simu_cgn=cgn_df[cgn_df["clustering_algorithm"]=="None"]
simu_cgn=simu_cgn[simu_cgn["simulation_steps"]<4500]
simu_cgn.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax5)

ax6.set_title("cgn- scenario controlled")
ax6.set_ylim([0,1400])
simu_cgn.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax6)

ax7.set_title("cgn- scenario controlled")
ax7.set_ylim([0,3])
simu_cgn.plot(x="simulation_steps", y=["DepartDelay"], ax=ax7)


plt.savefig('cgn-simplereward.png', bbox_inches='tight')
plt.show()
# Out:
# /home/ganjalf/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# # LuST Result Metric Comparison

# %%
f, axes = plt.subplots(figsize=(25,16), nrows=3, ncols=3)
ax1,ax2, ax33=  axes[0]
ax3,ax4,ax55=  axes[1]
ax5,ax6, ax7=  axes[2]

ax1.set_title("lust- reinforcement learner")
abs_lust=lust_df[lust_df["clustering_algorithm"]=="clusters_maxabs_3dimensions"]
abs_lust=abs_lust[lust_df["dqn"]=="full"]
abs_lust.plot(x="simulation_steps", y=["WaitingTime","TimeLoss", "Duration"], ax=ax1)

ax2.set_title("lust- reinforcement learner")
ax2.set_ylim([0,400])
abs_lust.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax2)

ax33.set_title("lust- reinforcement learner")
ax33.set_ylim([0,20])
abs_lust.plot(x="simulation_steps", y=["DepartDelay"], ax=ax33)



ax3.set_title("lust- random")
rnd_lust=lust_df[lust_df["clustering_algorithm"]=="random"]
rnd_lust.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax3)

ax4.set_title("lust- random")
rnd_lust.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax4)
ax55.set_title("lust- random")

rnd_lust.plot(x="simulation_steps", y=["DepartDelay"], ax=ax55)


ax5.set_title("lust- scenario controlled")
simu_lust=lust_df[lust_df["clustering_algorithm"]=="None"]
simu_lust=simu_lust[simu_lust["simulation_steps"]<9000]
simu_lust.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax5)

ax6.set_title("lust- scenario controlled")
ax6.set_ylim([0,400])
simu_lust.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax6)

ax7.set_title("lust- scenario controlled")
ax7.set_ylim([0,20])
simu_lust.plot(x="simulation_steps", y=["DepartDelay"], ax=ax7)


plt.savefig('lust-simplereward.png', bbox_inches='tight')
plt.show()
# Out:
# /home/ganjalf/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# # CGN Second Rewardfunction Metric- Comparison

# %%
file_name= "simulation-statistics-2nd-reward.csv"
df= pd.read_csv(file_name)


cgn_df= df[df["scenario"]=="cgn"]




cgn_df=cgn_df.sort(['simulation_steps'])

f, axes = plt.subplots(figsize=(25,24), nrows=5, ncols=3)


ax1,ax2, ax3=  axes[0]


ax1.set_title("cgn[1-4]- reinforcement learner")
abs_cgn=cgn_df[cgn_df["clustering_algorithm"]=="clusters_maxabs_3dimensions"]
abs_cgn14=abs_cgn[cgn_df["traffic_light_counts"]=="[1, 2, 3, 4]"]
abs_cgn14.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax1)

ax2.set_title("cgn[1-4]- reinforcement learner")

abs_cgn14.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax2)

ax3.set_title("cgn[1-4]- reinforcement learner")
abs_cgn14.plot(x="simulation_steps", y=["DepartDelay"], ax=ax3)

ax1,ax2, ax3=  axes[1]

ax1.set_title("cgn[1-4]- random")
rnd_cgn=cgn_df[cgn_df["clustering_algorithm"]=="random"]
rnd_cgn14=rnd_cgn[cgn_df["traffic_light_counts"]=="[1, 2, 3, 4]"]
rnd_cgn14.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax1)

ax2.set_title("cgn[1-4]- random ")

rnd_cgn14.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax2)

ax3.set_title("cgn[1-4]- random ")
rnd_cgn14.plot(x="simulation_steps", y=["DepartDelay"], ax=ax3)


ax1,ax2, ax3=  axes[2]
abs_cgn17=abs_cgn[abs_cgn["traffic_light_counts"]=="[1, 2, 3, 4, 5, 6, 7]"]

ax1.set_title("cgn [1-7]- reinforcement learner")
abs_cgn17.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax1)


ax2.set_title("cgn [1-7]- reinforcement learner")

abs_cgn17.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax2)

ax3.set_title("cgn [1-7]- reinforcement learner")
abs_cgn17.plot(x="simulation_steps", y=["DepartDelay"], ax=ax3)


ax1,ax2, ax3=  axes[3]

ax1.set_title("cgn[1-7]- random")
rnd_cgn=cgn_df[cgn_df["clustering_algorithm"]=="random"]
rnd_cgn17=rnd_cgn[cgn_df["traffic_light_counts"]=="[1, 2, 3, 4, 5, 6, 7]"]
rnd_cgn17.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax1)

ax2.set_title("cgn[1-7]- random ")

rnd_cgn17.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax2)

ax3.set_title("cgn[1-7]- random ")
rnd_cgn17.plot(x="simulation_steps", y=["DepartDelay"], ax=ax3)

ax1,ax2, ax3=  axes[4]

ax1.set_title("cgn[1-7]- simulation controlled")
sim_cgn=cgn_df[cgn_df["clustering_algorithm"]=="None"]

sim_cgn.plot(x="simulation_steps", y=["WaitingTime","TimeLoss","Duration"], ax=ax1)

ax2.set_title("cgn[1-7] simulation controlled")

sim_cgn.plot(x="simulation_steps", y=["Emergency Stops"], ax=ax2)

ax3.set_title("cgn[1-7]- simulation controlled")
sim_cgn.plot(x="simulation_steps", y=["DepartDelay"], ax=ax3)


plt.savefig('cgn-secondeward.png', bbox_inches='tight')
plt.show()
# Out:
# /home/ganjalf/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:10: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# /home/ganjalf/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/ganjalf/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:34: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/ganjalf/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:64: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# # 2. Reward Analysis

# %%
import json
f= open("rewards-lust.json",'r')
rewards= json.load(f)
pd.Series(rewards).describe()
# Out:
# count    4000.000000
# mean        0.731250
# std         0.489171
# min        -1.600000
# 25%         0.600000
# 50%         0.800000
# 75%         1.000000
# max         1.800000
# dtype: float64

# %%
f= open("rewards-cgn.json",'r')
rewards= json.load(f)
pd.Series(rewards).describe()
# Out:
# count    918000.000000
# mean          0.785190
# std           0.777763
# min          -2.000000
# 25%           0.800000
# 50%           1.000000
# 75%           1.200000
# max           2.200000
# dtype: float64

# %% [markdown]
# note that for only 2000 simulation steps, 918,000 rewards were computed! This is a benefit of clustering.

# %%
f= open("cgn-second-reward-function.json",'r')
rewards= json.load(f)
display(pd.Series(rewards).describe())
# Out:
# count    6.885000e+06
# mean    -3.051457e-01
# std      8.640870e-01
# min     -1.148596e+01
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      8.195229e-02
# max      6.976744e+00
# dtype: float64

# %% [markdown]
# Improved Reward Function statistics for 10000 runs of TAPAS Cologne with traffic lights 1-4 controlled
# - count    3.110000e+06
# - mean    -4.026700e-02
# - std      4.576000e-01
# - min     -5.970498e+00
# - 25%      0.000000e+00
# - 50%      1.781360e-02
# - 75%      1.088571e-01
# - max      6.976744e+00
# - dtype: float64
